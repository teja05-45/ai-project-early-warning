# %%
# !pip install pandas

# %%
import pandas as pd

df = pd.read_csv("data/raw/project_delivery_risk.csv")

print("Shape:", df.shape)
print("\nColumns:\n", df.columns.tolist())

print("\nSample data:")
df.head()

# %%
df.info()
df.describe(include="all")
